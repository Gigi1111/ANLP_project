# %% [markdown]
# ## Text Named Entity Similarity Score (evaluation) <br>
#
# In the following, we compute the similarity scores for named entities extracted from the translated body text of the articles in the evaluation dataset. <br>
#
# One can argue that extracting named entities after translation is a risky procedure (e.g. translating the German city name _"Essen"_ to the word _"Food"_). We keep track of these issues in **insert DIRECTORY or NAME OF FILE**

# %%
import pandas as pd
import spacy 
nlp = spacy.load('en_core_web_sm')

# %%
# 'complete' means no feature (title,keywords, text) is missing from the scrapped json files
# as we feed these features into the neural network, entries missing at least one of them
# cannot be used 
df = pd.read_csv('eval/_EVAL_details_complete_in_df.csv')

# %%
df.columns
# Out:
# Index(['pair_id', 'url1_lang', 'url2_lang', 'title1', 'title2', 'keywords1',
#        'keywords2', 'text1', 'text2', 'Geography', 'Entities', 'Time',
#        'Narrative', 'Overall', 'Style', 'Tone', 'translated_body1',
#        'translated_body2'],
#       dtype='object')

# %% [markdown]
# ### Use overlap score for named entities <br>
#
# As a measure of similarity for named entities we use the overlap coefficient. The chosen classes of named entities exclude the ones like _"CARDINAL"_, _"DATE"_, _"MONEY"_, _"ORDINAL"_, _"PERCENT"_, _"QUANTITY"_, and _"TIME"_. <br><br>
#
# The reason for this is that the normalization of NEs in these categories might prove problematic. For instance, understanding that _"20/3/22"_ and _"the previous Sunday"_ correspond to the same date is not obvious. Moreover, we agreed that named entities, such as the ones referring to proper nouns of people or places, might be enough to capture the basic data of the story.

# %%
ignore_labels = ['CARDINAL','DATE', 'MONEY', 'ORDINAL', 'PERCENT', 'QUANTITY', 'TIME']

def overlapScore(key1, key2):
    key1 = set(key1)
    key2 = set(key2)
    interset = key1.intersection(key2)
    union = key1.union(key2)
    if len(key1) <1 or len(key2) <1 or len(union) < 1 or len(interset)<1:
        return 0
    return (len(interset)/(len(union)))


text_key_df = pd.DataFrame(columns = ["pair_id","url1_lang", "url2_lang","text1","text2","translated_body1","translated_body2","key1","key2", "key_score"])

for index, row in df.iterrows(): 
    body1 = str(row['translated_body1'])
    body2 = str(row['translated_body2'])
    doc1 = nlp(body1) 
    doc2 = nlp(body2) 
    ner1 = [(((ent.text.lower()).replace("'s", "")).replace("-"," ")).replace(".","") for ent in doc1.ents if ent.label_ not in ignore_labels]
    ner2 = [(((ent.text.lower()).replace("'s", "")).replace("-"," ")).replace(".","") for ent in doc2.ents if ent.label_ not in ignore_labels]
    score = overlapScore(ner1, ner2)
    if score > 0:
        print('---------------------',index,'-----------------------')
        print(body1[:20])
        print(ner1[:3])
        print(body2[:20])
        print(ner2[:3])
        print(score)
    
    pair = str(row['pair_id'])
    entry = {"pair_id": pair,"url1_lang":row['url1_lang'],"url2_lang":row['url2_lang'],"text1":row["text1"],"text2":row["text2"]
             ,"translated_body1":row['translated_body1'],"translated_body2":row['translated_body2'],"key1":ner1,"key2":ner2,"key_score":score}
    text_key_df = text_key_df.append(entry, ignore_index = True) ####
# Out:
# --------------------- 0 -----------------------
# MARTINSBURG, W.Va. —
# ['martinsburg', 'wva', 'new year’s day']
# PORT-AU-PRINCE, Hait
# ['haiti', 'haitian', 'jovenel moïse']
# 0.045454545454545456
# --------------------- 1 -----------------------
# Uber has sold its on
# ['india', 'zomato', 'china']
# Rapid digitisation a
# ['india', 'google', 'boston consulting group']
# 0.12195121951219512
# --------------------- 2 -----------------------
# BENGALURU (Reuters)
# ['bengaluru', 'reuters', 'india']
# BANGALORE: India pla
# ['india', 'indian space research organisation', 'k sivan']
# 0.3181818181818182
# --------------------- 4 -----------------------
# From The Guardian
#
# F
# ['guardian', 'boeing', 'whole foods']
# Police have arrested
# ['orange country', 'ny', 'jews']
# 0.03125
# --------------------- 5 -----------------------
# An exhibition outlin
# ['spike island', 'the war of independence', 'cork harbour']
# Taoiseach Leo Varadk
# ['taoiseach leo varadkar', 'state', 'new year']
# 0.1282051282051282
# --------------------- 7 -----------------------
# Paid leave for new p
# ['brisbane', 'uk', 'australian']
# Former world number
# ['grigor dimitrov', 'bulgarian', 'the us open']
# 0.0625
# --------------------- 8 -----------------------
# Hyderabad: Telangana
# ['telangana information technology', 'kt rama rao', 'ai']
# Master blaster Sachi
# ['sachin tendulkar', 'madda ram', 'madda ram']
# 0.1794871794871795
# --------------------- 9 -----------------------
# Banerjee had last we
# ['the trinamool congress', 'foundation day', 'citizenship act']
# Terming the CAA a “t
# ['the constitution of india', 'swara bhasker', 'the citizenship (amendment) act']
# 0.041666666666666664
# --------------------- 12 -----------------------
# Pope Francis has use
# ['francis', 'new year', 'st peter basilica']
# Pope Francis apologi
# ['francis', 'new year eve', 'afp photo/andreas solaro']
# 0.4
# --------------------- 13 -----------------------
# Police found the bod
# ['neeraj agarwal', 'agra', 'vrindavan']
# Neeraj, his wife Neh
# ['mathura', 'neeraj agarwal', 'neha agarwal']
# 0.14285714285714285
# --------------------- 16 -----------------------
# Nine people have die
# ['indonesia', 'new year eve', 'jakarta']
# At least nine people
# ['jakarta', 'the new year', 'new year eve']
# 0.2692307692307692
# --------------------- 17 -----------------------
# A New Year is upon u
# ['new year', 'new year', 'daily']
# Revelers packed the
# ['the las vegas strip', 'new year’s eve', 'the las vegas strip   video']
# 0.02
# --------------------- 18 -----------------------
# If in the throes of
# ['bitcoin', 'bloomberg', 'peter atwater']
# (Bloomberg) -- Want
# ['bloomberg', 'asia', 'australia']
# 0.07142857142857142
# --------------------- 21 -----------------------
# Pope Francis has apo
# ['francis', 'vatican', 'new year’s eve']
# Pope Francis found h
# ['francis', 'new years eve', 'pope']
# 0.14285714285714285
# --------------------- 22 -----------------------
# (MENAFN - The Penins
# ['menafn   the peninsula', 'the institute of chartered accountants', 'india']
# New Delhi: Continuin
# ['new delhi', 'india', 'pakistan']
# 0.06896551724137931
# --------------------- 23 -----------------------
# In the most anticipa
# ['north korea’s', 'kim jong un', 'the workers’ party']
# We didn’t wind up ge
# ['kim jong un', 'trump', 'north korea']
# 0.2692307692307692
# --------------------- 24 -----------------------
# Good morning and wel
# ['nsw', 'australian', 'nsw']
# Advertisement
#
# Resid
# ['australian', 'the new south wales', 'victoria']
# 0.1076923076923077
# --------------------- 26 -----------------------
# Share Tweet Email Co
# ['copy link copied', 'new year day', 'disney+']
# To kick off 2020, Di
# ['disney', 'disney+', 'marvel']
# 0.3333333333333333
# --------------------- 27 -----------------------
# Sienna Santer is a s
# ['sienna santer', 'harvard', 'youtube']
# Andrei Jikh was teac
# ['andrei jikh', 'google', 'business insider']
# 0.28
# --------------------- 28 -----------------------
# All it took for the
# ['anti semitic', 'jews', 'hasidic']
# CROWN HEIGHTS, Brook
# ['crown heights', 'brooklyn', 'anti semitic']
# 0.25
# --------------------- 30 -----------------------
# It's a new year and,
# ['illinois', 'sunnyside', 'facebook']
# Customer Elise Swope
# ['customer elise swopes', 'sunnyside cannabis dispensary', 'chicago']
# 0.22580645161290322
# --------------------- 33 -----------------------
# On Tuesday — followi
# ['us', 'iraq', 'syria']
# US troops on Wednesd
# ['us', 'pro iranian', 'the us embassy']
# 0.35294117647058826
# --------------------- 34 -----------------------
# The president spoke
# ['defense', 'mark esper', 'the 82nd airborne division']
# Donald Trump speaks
# ['donald trump', 'melania trump', 'new year eve']
# 0.1951219512195122
# --------------------- 35 -----------------------
# Your browser does no
# ['manjot kalra', 'u 19 world cup', 'ddca ombudsman']
# Your browser does no
# ['robert pattinson', 'batman', "matt reeves'"]
# 0.025
# --------------------- 36 -----------------------
# Dracula review – a b
# ['dracula', 'steven moffat', 'mark gatiss']
# Dracula
#
# Rating:
#
# Pi
# ['dracula\n\nrating:\n\n', 'claes bang', 'dracula']
# 0.25
# --------------------- 38 -----------------------
# Whether you’re tryin
# ['new year’s', 'new year’s', 'tiffany norton\n\nnew']
# When I was a kid, Ne
# ['new year', 'the new year', 'new year’s']
# 0.037037037037037035
# --------------------- 39 -----------------------
# GET THE SHOW ON THE
# ['australian', 'howard freeman', 'australian']
# At least eight more
# ['australia', 'australia', 'armageddon']
# 0.041666666666666664
# --------------------- 40 -----------------------
# This is the year to
# ['taylor swift', 'china', 'nataly kogan']
# × How to succeed at
# ['new year’s', 'new york', 'new year’s']
# 0.06666666666666667
# --------------------- 41 -----------------------
# The Reds head into 2
# ['reds', 'jürgen klopp’s', 'melwood']
# Former Arsenal manag
# ['arsene wenger', 'liverpool', 'premier league']
# 0.14285714285714285
# --------------------- 43 -----------------------
# Customer Elise Swope
# ['customer elise swopes', 'sunnyside cannabis dispensary', 'chicago']
# Illinois Gov. JB Pri
# ['illinois', 'pritzker', 'pritzker']
# 0.15384615384615385
# --------------------- 44 -----------------------
#
#
#
#
#
#
#
#
#
#
#
#
# During t
# ['ukrainian nazis', 'west', 'hong kong']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ['chinese', 'xi jinping', 'macau']
# 0.09433962264150944
# --------------------- 45 -----------------------
# MACON, Ga. (AP) - A
# ['macon', 'ga', 'ap']
# HANSON, Mass. (AP) -
# ['hanson', 'mass', 'ap']
# 0.3125
# --------------------- 46 -----------------------
# The video will start
# ['free', 'invalid email', 'halifax']
# The new year has got
# ['lloyds', 'halifax', 'bank of scotland']
# 0.3
# --------------------- 47 -----------------------
# Jan 01, 2020 , 9:26P
# ['9:26pm home ministry', 'pfi', 'law']
# Law Minister on Wedn
# ['constitutional', 'parliament', 'the citizenship amendment act']
# 0.1111111111111111
# --------------------- 48 -----------------------
# VIENNA - Austrian co
# ['vienna   austrian', 'sebastian kurz', 'greens']
# Austria's Conservati
# ['austria', 'conservatives', 'sebastian kurz']
# 0.3103448275862069
# --------------------- 51 -----------------------
# Russia’s Avangard hy
# ['russia', 'russian', 'avangards']
# By Sergei Guriev
#
# Fr
# ['sergei guriev', 'germany', 'adolf hitler']
# 0.1111111111111111
# --------------------- 52 -----------------------
# MIRAMAR, FLA. (WSVN)
# ['miramar', 'fla', 'wsvn']
# DEERFIELD BEACH, FLA
# ['deerfield beach', 'fla', 'wsvn']
# 0.2222222222222222
# --------------------- 53 -----------------------
# PERU, Ind (AP) - Two
# ['peru', 'ind (ap', 'indiana']
# MISHAWAKA, Ind. (AP)
# ['mishawaka', 'ind', 'ap']
# 0.15384615384615385
# --------------------- 57 -----------------------
# Three-car accident i
# ['norwalk', 'martin luther king drive', 'martin luther king drive']
# The Federal Road Saf
# ['the federal road safety corps', 'ogun', 'ijebu ode ore expressway']
# 0.05555555555555555
# --------------------- 59 -----------------------
# There's no doubt Gra
# ['grafton thomas', 'new york', 'an african american']
# Police have arrested
# ['orange country', 'ny', 'jews']
# 0.1
# --------------------- 60 -----------------------
# Pomidor Quixote
#
# Dai
# ['pomidor quixote\n\ndaily stormer', 'breitbart', 'the united kingdom']
# LILLE, FRANCE - Over
# ['lille', 'france', 'the english channel']
# 0.05714285714285714
# --------------------- 62 -----------------------
# FIFA 20 fanatics hav
# ['team of the week', 'ea sports', 'europe']
# The Premier League k
# ['brighton', 'burnley', 'aston villa']
# 0.06666666666666667
# --------------------- 63 -----------------------
#
#
# George Mason Natio
# ['tim evanson', 'aristocracy', 'monarchy']
# Karl R. H. Frick on
# ['karl r h frick', 'karl r h frick’s die erleuchteten', 'ende des 18']
# 0.005847953216374269
# --------------------- 64 -----------------------
# DETROIT – Police sai
# ['detroit', 'detroit', 'oakland']
# LIVONIA (WWJ) - The
# ['wwj', 'detroit', 'the taco bell']
# 0.35
# --------------------- 67 -----------------------
# (CNN) Much has been
# ['cnn', 'donald trump', 'christianity']
# Who Cares: OZY's 202
# ['cares', 'ozy', 'cares']
# 0.1282051282051282
# --------------------- 69 -----------------------
# 2019: Oregon Interna
# ['oregon international air show', 'mcminnville', 'hillsboro']
# 2019: Deputies wound
# ['hagg lake', 'gaston', "the news times'"]
# 0.13513513513513514
# --------------------- 71 -----------------------
# Text Size: A- A+
#
# Du
# ['iraqi', 'us embassy', 'baghdad']
# Iran’s Supreme Leade
# ['iran', 'supreme leader', 'ayatollah ali khamenei']
# 0.25
# --------------------- 73 -----------------------
# There’s what you’ll
# ['pasadena', 'fbi', 'the rose bowl']
# Bannered under the t
# ['the power of hope', 'latina', 'latina']
# 0.16521739130434782
# --------------------- 75 -----------------------
# Please enable Javasc
# ['javascript', 'chicago', 'chicago']
# Oren Segal, vice pre
# ['the anti defamation league', 'cnn', 'state of the union']
# 0.20833333333333334
# --------------------- 77 -----------------------
# Sign up to FREE dail
# ['free', 'invalid email', 'apple']
# Every big company is
# ['verizon', 'apple', 'netflix']
# 0.2222222222222222
# --------------------- 79 -----------------------
# On Wednesday, cries
# ['kagaz nahin dikhayenge', 'tanasahi', 'india gate']
# Thousands of Indians
# ['indians', 'the new year', 'narendra modi’s']
# 0.2833333333333333
# --------------------- 80 -----------------------
# From Informed Commen
# ['the middle east', 'abdelaziz bouteflika', 'algeria']
# Iraqi protesters on
# ['iraqi', 'the us embassy', 'baghdad']
# 0.1694915254237288
# --------------------- 83 -----------------------
# A Maine man won $1 m
# ['maine', 'blaine marston', 'the maine lottery']
# According to WMTW, H
# ['wmtw', 'howland', 'blaine marston']
# 0.2
# --------------------- 85 -----------------------
# Police at the scene
# ['hotel sky', 'industrial area phase i', 'chandigarh']
# Registration for the
# ['the jnu students’ union', 'cashier', 'registrar pramod kumar']
# 0.034482758620689655
# --------------------- 86 -----------------------
# In the final analysi
# ['balakot', 'india', 'cds']
# Newly-appointed Chie
# ['the defence staff', 'bipin rawat', 'army']
# 0.10256410256410256
# --------------------- 87 -----------------------
# Filmmaker Todd Phill
# ['todd phillips', 'dc', 'joker']
# Your browser does no
# ['joker', 'todd phillips', 'joaquin phoenix']
# 0.15
# --------------------- 88 -----------------------
# After profiting from
# ['brexit', 'us', 'us']
# The mood of the mark
# ['photo /', 'photo /', 'uk']
# 0.14814814814814814
# --------------------- 89 -----------------------
# Sign up to FREE dail
# ['free', 'invalid email', 'wales']
# Sign up to FREE dail
# ['free', 'invalid email', 'r']
# 0.016666666666666666
# --------------------- 90 -----------------------
# United Natural Foods
# ['united natural foods inc', 'nyse', 'oppenheimer']
# Hertz Global Holding
# ['hertz global holdings', 'inc (nyse', 'nyse htz']
# 0.11666666666666667
# --------------------- 91 -----------------------
# NEW YORK, Jan. 1, 20
# ['new york', 'https://wwwreportlinkercom/p05796465/?utm_source=prn', 'north america']
# NEW YORK, Jan. 1, 20
# ['new york', '2025the video analytics market in law enforcement', 'defense & public safety']
# 0.14285714285714285
# --------------------- 92 -----------------------
# (CNN) Is it really N
# ['cnn', 'new year day', 'the rose parade']
# PASADENA, Calif. (KT
# ['pasadena', 'calif', 'ktla']
# 0.06666666666666667
# --------------------- 93 -----------------------
# Please enable Javasc
# ['javascript', 'cleveland', 'ohio']
# CLEVELAND, Ohio (WJW
# ['cleveland', 'ohio', 'wjw']
# 0.2727272727272727
# --------------------- 94 -----------------------
# Rehman Malik, throug
# ['rehman malik', 'abubaccar marie tambadou', 'pakistan']
# Two braveheart soldi
# ['the indian army', 'the line of control', 'pakistani']
# 0.10714285714285714
# --------------------- 96 -----------------------
# By BECKY BOHRER, Ass
# ['associated press', 'juneau', 'alaska']
# RALEIGH — The federa
# ['north carolina’s', 'us', 'district court']
# 0.125
# --------------------- 98 -----------------------
# 13 Shares Email
#
# In
# ['orange county', 'voice of oc\n\njulie leopo', 'voice of oc\n\njulie leopo']
# Support our high sch
# ['orange county', 'isaac owens', 'owens']
# 0.05263157894736842
# --------------------- 101 -----------------------
# Send this page to so
# ['shelly ehbrecht', 'surrey memorial hospital', 'ehbrecht']
# Send this page to so
# ['boxing week', 'langford', 'bc']
# 0.06666666666666667
# --------------------- 102 -----------------------
# The Mayor of the cit
# ['london', 'ont', 'londoners']
# He’s been teaching L
# ['leroy hibbert', 'london', 'distinguished londoner']
# 0.17543859649122806
# --------------------- 105 -----------------------
# NEW DELHI: The Insti
# ['new delhi', 'the institute of banking personnel selection', 'ibps']
# Institute of Banking
# ['institute of banking personnel selection', 'ibps', 'clerk']
# 0.11538461538461539
# --------------------- 106 -----------------------
#
#
# Warning
#
# (Image by
# ['pakistan', 'fatf', 'syria']
# NEW DELHI: Continuin
# ['india', 'pakistan', 'nuclear installations']
# 0.07692307692307693
# --------------------- 107 -----------------------
# With food politics,
# ['asian', 'california', 'orange county’s']
# For this is a book t
# ['greece', 'italian', 'french']
# 0.10256410256410256
# --------------------- 109 -----------------------
# WASHINGTON The Trump
# ['washington', 'iraq', 'the us embassy']
# As the new civil yea
# ['iraq', 'america', 'middle east']
# 0.1
# --------------------- 110 -----------------------
# Bloomberg opinion:
#
#
# ['bloomberg', 'nzx50', 'donald trump']
# U.S. government debt
# ['us', 'treasury', 'treasury']
# 0.06896551724137931
# --------------------- 111 -----------------------
# Kolam in front of ho
# ['kolam', 'caa', 'nrc']
# In the anti citizens
# ['chennai', 'pakistan', 'india']
# 0.2647058823529412
# --------------------- 113 -----------------------
# Article content
#
# ST.
# ['article', 'catharines', 'ont']
# HALIFAX -- Halifax p
# ['halifax', 'halifax regional police', 'the canadian press']
# 0.08333333333333333
# --------------------- 114 -----------------------
# It was a busy night
# ['greater manchester police', 'new year eve', 'wellington road south']
# Sign up to FREE dail
# ['free', 'mirror   daily', 'subscribe']
# 0.15151515151515152
# --------------------- 115 -----------------------
# There will be no Lat
# ['latin america', 'the new year day', 'reuters']
# SEOUL: Oil prices ro
# ['the united states', 'china', 'the middle east']
# 0.13157894736842105
# --------------------- 117 -----------------------
# NEW YORK, Jan. 1, 20
# ['new york', 'argentine', 'south american']
# Twenty years into th
# ['swat', 'constitution', 'american']
# 0.02857142857142857
# --------------------- 118 -----------------------
# It was only January
# ['anti semitic black hebrew israelite', 'covington catholic', 'the black hebrew israelites']
# One of the two suspe
# ['anti semitic', 'jewish', 'jersey city']
# 0.09523809523809523
# --------------------- 119 -----------------------
# Sign up to FREE dail
# ['free', 'invalid email\n\npolice', 'ricky gamage']
# Sign up to FREE dail
# ['free', 'plymouthherald   daily subscribe', 'invalid email\n\npolice']
# 0.13636363636363635
# --------------------- 121 -----------------------
#
#
# It was Blair who w
# ['blair', 'corbyn', 'image']
# Brexit
#
# Brexit
#
# Brex
# ['brexit\n\nbrexit\n\nbrexit\n\nlondon', 'british', 'boris johnson']
# 0.1
# --------------------- 124 -----------------------
# California is poised
# ['california', 'us census bureau', 'the district of columbia']
# By JOSH FRIEDMAN
#
# Fu
# ['josh', 'california', 'la times']
# 0.4090909090909091
# --------------------- 125 -----------------------
# US election, Brexit
# ['us', 'brexit', 'china']
# The mood of the mark
# ['photo /', 'photo /', 'uk']
# 0.14814814814814814
# --------------------- 129 -----------------------
# Large crowds gathere
# ['european', 'big ben', 'london']
# Fireworks, smoke and
# ['fireworks', 'new year', 'copacabana beach']
# 0.20689655172413793
# --------------------- 130 -----------------------
# Jubilant Foodworks L
# ['nifty', 'nifty', 'sensex']
# Titan Company Ltd ha
# ['titan company ltd', 'sensex', 'ttk prestige ltd']
# 0.25
# --------------------- 131 -----------------------
# Prime Minister Naren
# ['narendra modi', 'karnataka', "drdo young scientists' laboratories"]
# Shares of Bajaj Elec
# ['bajaj electricals', 'bse', 'bse']
# 0.22727272727272727
# --------------------- 132 -----------------------
# As Northern Ireland
# ['northern ireland', 'arlene foster', 'northern ireland']
# Irish Foreign Affair
# ['irish', 'simon coveney', 'arlene foster']
# 0.23529411764705882
# --------------------- 133 -----------------------
# Sign up to FREE emai
# ['free', 'cornwalllive   court insider subscribe thank', 'invalid email']
# Sign up to FREE dail
# ['free', 'invalid email', 'new year']
# 0.012422360248447204
# --------------------- 135 -----------------------
# QNA
#
# A two-day works
# ['qna', 'texas a&m university', 'qatar']
# (MENAFN - The Penins
# ['menafn   the peninsula', 'qatar', 'ooredoo']
# 0.11428571428571428
# --------------------- 137 -----------------------
# From Common Dreams
#
#
# ['us', 'dmca\n\n\n\nimpeachment', 'trump']
#
#
# Protesters burn pr
# ['the us embassy', 'baghdad', 'khalid mohammed/ap']
# 0.14414414414414414
# --------------------- 138 -----------------------
# ( MENAFN - Saudi Pre
# ['menafn   saudi press agency', 'riyadh', 'salman bin']
# (MENAFN - Saudi Pres
# ['menafn   saudi press agency', 'riyadh', 'faisal bin farhan bin abdullah']
# 0.11764705882352941
# --------------------- 139 -----------------------
# Palghar: The Shiv Se
# ['maharashtra', 'matoshree of delhi', 'matoshree']
# Mumbai: Former chief
# ['mumbai', 'devendra fadnavis', "the new year day '"]
# 0.37209302325581395
# --------------------- 140 -----------------------
# Hours before donning
# ['new year’s day', 'broad street', 'mummers mass']
# While some will like
# ['new year eve', 'philadelphia', 'the mummers parade']
# 0.0625
# --------------------- 141 -----------------------
# LOS ANGELES (CBSLA)
# ['los angeles', 'los angeles', 'grand park']
# DOWNTOWN LOS ANGELES
# ['los angeles', 'the west coast', 'new year eve']
# 0.29411764705882354
# --------------------- 143 -----------------------
# Protest in New York
# ['new york city', 'bill de blasio', 'new york']
# What to Know There w
# ['jews', 'new york city', 'hanukkah']
# 0.32558139534883723
# --------------------- 144 -----------------------
# Bureau of Meteorolog
# ['bureau of meteorology', 'australia', 'the bureau of meteorology']
# India hockey team ca
# ['india', 'manpreet singh', 'the tokyo olympics']
# 0.06666666666666667
# --------------------- 145 -----------------------
# Kata’ib Hizbullah is
# ['hizbullah', 'shia', 'iran']
# Iraqi protesters on
# ['iraqi', 'the us embassy', 'baghdad']
# 0.1111111111111111
# --------------------- 146 -----------------------
# Kata’ib Hizbullah is
# ['hizbullah', 'shia', 'iran']
# Iraqi protesters on
# ['iraqi', 'the us embassy', 'baghdad']
# 0.1111111111111111
# --------------------- 148 -----------------------
# DULUTH -- “This is a
# ['arlene coco buscombe', 'wis', 'cajun']
# Have you thought abo
# ['italy', 'italy', 'italy']
# 0.04
# --------------------- 149 -----------------------
# Bollywood actor Rajk
# ['rajkummar rao', 'anurag basu’s', 'rao']
# Rajkummar Rao in Lud
# ['rajkummar rao', 'anurag basu', 'abhishek bachchan']
# 0.22857142857142856
# --------------------- 150 -----------------------
# National Anti Doping
# ['national anti doping agency', 'nada', 'twitter']
# The Central Bureau o
# ['the central bureau of investigation', 'cbi', 'business standard']
# 0.07142857142857142
# --------------------- 151 -----------------------
# Los Angeles: UK chip
# ['los angeles', 'uk', 'imagination technologies group plc']
# Apple could start us
# ['apple', 'iphones', 'intel']
# 0.19230769230769232
# --------------------- 154 -----------------------
# PATNA: The prevalenc
# ['bihar', 'lancet psychiatry', 'bihar']
# NEW DELHI: BJP presi
# ['new delhi', 'bjp', 'amit shah']
# 0.09433962264150944
# --------------------- 157 -----------------------
# news, story, article
# ['gna\n\n\n\nbolgatanga', 'gna', 'the new year']
# news, story, article
# ['francis ameyibor', 'gna\n\n\n\naccra', 'the liberal party']
# 0.125
# --------------------- 158 -----------------------
# Rumours circulating
# ['amd radeon', 'amd', 'gpu']
# As we look back at 2
# ['amd', 'amd', 'amd']
# 0.13793103448275862
# --------------------- 159 -----------------------
# PATNA: Foggy weather
# ['east central railway', 'ecr', 'ecr']
# New Delhi, Jan 01: D
# ['new delhi', 'delhi police', 'new year']
# 0.07407407407407407
# --------------------- 161 -----------------------
# Jason Holder has bee
# ['jason holder', "west indies'", 'ireland']
# No names were disclo
# ['bjp', 'russia', 'pm modi']
# 0.02631578947368421
# --------------------- 166 -----------------------
# Cardiovascular Devic
# ['global industry demand, industry news', 'business updates', 'size, share']
# DUBLIN, Dec. 31, 201
# ['dublin', 'researchandmarketscom', 'the global cleanroom lighting market']
# 0.15178571428571427
# --------------------- 167 -----------------------
# Basant Maheshwari, P
# ['basant maheshwari', 'pms', 'founder']
# Independent market e
# ['sameer', 'nifty', 'china']
# 0.13333333333333333
# --------------------- 168 -----------------------
# Actor Aayush Shamra
# ['aayush', 'arpita khan sharma', 'ayat']
# Salman Khan's birthd
# ['salman khan', 'bhaijaan', 'arpita khan']
# 0.0967741935483871
# --------------------- 169 -----------------------
# With bullish hiring
# ['the new year', 'myhiringclubcom & sarkari naukriinfo employment trend survey', 'myhiringclubcom & sarkari naukriinfo']
# Mindspace Business P
# ['mindspace business parks reit', 'mumbai', 'k raheja corp']
# 0.06666666666666667
# --------------------- 170 -----------------------
# China has formally i
# ['china', 'cbdc', 'english']
# People’s Bank of Chi
# ['people’s bank of china', 'china', 'the people’s bank of china']
# 0.1111111111111111
# --------------------- 171 -----------------------
# DETROIT – A woman wa
# ['detroit', 'strasburg street', 'the detroit police department']
# DETROIT – Detroit po
# ['detroit', 'detroit', 'new year’s eve']
# 0.14285714285714285
# --------------------- 173 -----------------------
# Police are investiga
# ['miami', 'miami dade police', 'southwest 216th street']
# Police are investiga
# ['miami', 'little haiti', 'northwest 2nd court']
# 0.16666666666666666
# --------------------- 174 -----------------------
# Recreational marijua
# ['illinois', 'the new year', 'cannabis']
# With 2019 nearly rol
# ['illinois', 'pritzker', 'the illinois’ cannabis regulation']
# 0.21951219512195122
# --------------------- 175 -----------------------
# news, local-news,
#
# A
# ['the manning river', 'the new year eve', 'midcoast council']
# A man has died durin
# ['new year eve', 'australia', 'the emporium hotel']
# 0.08695652173913043
# --------------------- 177 -----------------------
# 13 Shares Email
#
# Voi
# ['orange county’s', 'orange county’s', 'santa ana']
# Editor’s note: This
# ['unsheltered', 'costa mesa', 'fountain valley']
# 0.036231884057971016
# --------------------- 178 -----------------------
# Want to grow your bu
# ['new year', 'entrepreneur', 'new year’s']
# New Years-fresh star
# ['new years', 'new year’s resolutions', 'new year’s']
# 0.08333333333333333
# --------------------- 180 -----------------------
# Congress leader Nell
# ['congress', 'nellai kannan', 'bjp']
# The BJP held a prote
# ['bjp', 'chennai', 'marina beach']
# 0.3111111111111111
# --------------------- 181 -----------------------
# Lisa Armstrong paid
# ['lisa armstrong', 'new year day', 'derek on instagram']
# Lisa lost her father
# ['lisa', 'rex/@lisaarmstrong', 'lisa armstrong']
# 0.15625
# --------------------- 182 -----------------------
# Claudius Moore, a se
# ['claudius moore', 'american family care', 'moore']
# × Live table games b
# ['hoosier', 'anderson', 'ind']
# 0.022222222222222223
# --------------------- 183 -----------------------
# One of the most succ
# ['detroit', 'comerica bank', 'the detroit lions']
# Matthew Stafford sto
# ['matthew stafford', 'the detroit lions', 'stafford']
# 0.078125
# --------------------- 184 -----------------------
# Erin Kane, Vice Pres
# ['erin kane', 'octagon basketball', 'entrepreneur network']
# Personal branding bu
# ['entrepreneur', 'instagram', 'social media']
# 0.06666666666666667
# --------------------- 185 -----------------------
# More than 4,000 peop
# ['mallacoota', 'australia', 'david jeffrey']
# Canberra: At least s
# ['australian', 'new south wales', 'bbc']
# 0.25
# --------------------- 186 -----------------------
# More than 4,000 peop
# ['mallacoota', 'australia', 'david jeffrey']
# Canberra: At least s
# ['australian', 'new south wales', 'bbc']
# 0.25
# --------------------- 187 -----------------------
# Thiruvananthapuram (
# ['india', 'ani', 'pinarayi vijayan']
# The Kerala Real Esta
# ['the kerala real estate regulatory authority', 'pinarayi vijayan', 'k rera']
# 0.3333333333333333
# --------------------- 188 -----------------------
# Emma Roche has had a
# ['emma roche', 'matt agnew', 'bachelor']
# Last year, we featur
# ['australian', 'sadie', 'victoria']
# 0.0625
# --------------------- 189 -----------------------
# A woman accused of s
# ['jewish', 'brooklyn', 'tiffany harris']
# A Brooklyn miscreant
# ['brooklyn', 'orthodox', 'jewish']
# 0.2647058823529412
# --------------------- 190 -----------------------
# New Delhi: Delhi Dep
# ['new delhi', 'delhi', 'manish sisodia']
# Guwahati: The Assam
# ['guwahati', 'esma', 'the essential services maintenance (assam) act']
# 0.2916666666666667
# --------------------- 191 -----------------------
# LOS ANGELES (AFP) -
# ['los angeles', 'american', 'syd mead']
# LOS ANGELES — The ce
# ['los angeles', 'southern california’s', 'the central coast']
# 0.04
# --------------------- 192 -----------------------
# New Delhi (Sputnik):
# ['new delhi', 'sputnik', 'india']
# India seeking to bec
# ['india', 'russia', 'the united states']
# 0.3333333333333333
# --------------------- 194 -----------------------
# With its healthcare
# ['the middle east', 'qatar', 'legatum institute']
# Narrowing down a lis
# ['us', 'barack obama', 'obama']
# 0.03773584905660377
# --------------------- 196 -----------------------
# BODY FOUND OF MISSIN
# ['shamli', 'uttar pradesh', 'panipat']
# Police said that the
# ['haryana police', 'representational image', 'haryana police']
# 0.27586206896551724
# --------------------- 197 -----------------------
# WASHINGTON – Preside
# ['washington', 'donald trump', 'democratic']
# Pete Buttigieg is no
# ['pete buttigieg', 'south bend', 'indiana']
# 0.2708333333333333
# --------------------- 198 -----------------------
# Chinese smartphone m
# ['chinese', 'xiaomi', 'the mi mix alpha']
# Chinese handset make
# ['chinese', 'vivo', 'apex']
# 0.05555555555555555
# --------------------- 199 -----------------------
# For three decades, p
# ['robert bakker', 'cleveland', 'ohio) museum of natural history']
# The dinosaur formerl
# ['nanotyrannus friedrich saurer/alamy\n\nsometimes', 'the hell creek formation', 'montana']
# 0.3076923076923077
# --------------------- 201 -----------------------
# Police are looking f
# ['jewish', 'crown heights', 'hanukkah']
#
#
#
#
# — The numbers ke
# ['jews', 'broadway', 'williamsburg']
# 0.12244897959183673
# --------------------- 202 -----------------------
# Thanks to December s
# ['southern california', 'jan null', 'northern california’s']
# It’s been a lousy ho
# ['southern california’s', 'newcastle', 'san bernardino']
# 0.13513513513513514
# --------------------- 204 -----------------------
# Marvel Ultimate Alli
# ['marvel ultimate alliance', 'nintendo switch', 'dlc']
# Who is God to you? P
# ['james meehan', 'switch', 'christians']
# 0.041666666666666664
# --------------------- 205 -----------------------
# Aligarh Muslim Unive
# ['aligarh muslim university', 'the aligarh muslim university amu', 'the university administration']
# An apparently drunke
# ['cctv', 'shanghai', 'china']
# 0.07692307692307693
# --------------------- 206 -----------------------
# Browse > Home News /
# ['israelis', 'world cup', 'qatari']
# Israel avoiding repe
# ['israel', 'bethlehem', 'artist banksy']
# 0.13333333333333333
# --------------------- 210 -----------------------
# Four people inside a
# ['woodland hills', 'los angeles', 'the extended stay america']
# Four people who were
# ['woodland hills', 'the extended stay america', 'ventura blvd']
# 0.3
# --------------------- 211 -----------------------
# JTA — An appeals cou
# ['jta', 'jewish', 'quranic']
# While a shooter was
# ['jews', 'jersey city', 'new jersey']
# 0.15
# --------------------- 212 -----------------------
# New Delhi (Sputnik):
# ['new delhi', 'sputnik', 'indian']
# First Chief of Defen
# ['defence staff', 'gen bipin rawat', 'army']
# 0.2558139534883721
# --------------------- 214 -----------------------
# Kolkata: The BJP lea
# ['bjp', 'west bengal', 'citizenship (amendment) act']
# Amid the opposition
# ['citizenship amendment act', 'caa', 'the ministry of home affairs']
# 0.2830188679245283
# --------------------- 217 -----------------------
#
#
#
#
# BOSTON (CBS) — O
# ['cbs', 'nfl', 'ryan tannehill']
#
#
#
#
# BOSTON (CBS) — A
# ['cbs', 'patriots', 'nfc']
# 0.15853658536585366
# --------------------- 218 -----------------------
# Somridho, a model an
# ['somridho', 'somriddho dasgupta', 'london']
# New Delhi: A year af
# ['new delhi', 'vijay mallya', 'india']
# 0.14285714285714285
# --------------------- 219 -----------------------
# As Jamie Oliver and
# ['jamie oliver', 'jools', 'jools']
# 2019 is the year of
# ['instagram', 'japanese', 'singapore']
# 0.05263157894736842
# --------------------- 221 -----------------------
# Gary McLaren, 50, re
# ['gary mclaren', 'british', 'thailand']
# Briton killed after
# ['briton', 'new year eve', 'thailand']
# 0.32
# --------------------- 223 -----------------------
# KCB will release and
# ['kcb', 'bankers', 'kenyan commercial bank']
# Ulinzi Stars welcome
# ['kpl', 'kenyan', 'league']
# 0.07692307692307693
# --------------------- 224 -----------------------
# Bollywood has a long
# ['the dirty picture', 'bollywood', 'reshma']
# Researchers have fou
# ['scientific reports', 'leena', 'the georgetown university']
# 0.28
# --------------------- 225 -----------------------
# Before I list the ch
# ['yellow vest', 'paris', 'france']
# While a shooter was
# ['jews', 'jersey city', 'new jersey']
# 0.10810810810810811
# --------------------- 227 -----------------------
# The demonstrators ha
# ['death to america', 'iranian', 'us']
# Paramilitary groups
# ['us', 'iraq', 'washington']
# 0.25
# --------------------- 228 -----------------------
# King Sunny Ade said
# ['king sunny ade', 'juju', 'lagos']
# I am searching for a
# ['nigeria', 'luxury lifestyle and entertainment resort', 'victoria island']
# 0.09090909090909091
# --------------------- 230 -----------------------
# Torrential rains and
# ['jakarta', 'indonesia', 'new year eve']
# At least nine people
# ['jakarta', 'the new year', 'new year eve']
# 0.2222222222222222
# --------------------- 231 -----------------------
# Torrential rains and
# ['jakarta', 'indonesia', 'new year eve']
# At least nine people
# ['jakarta', 'the new year', 'new year eve']
# 0.2222222222222222
# --------------------- 233 -----------------------
# The housemates of "B
# ['bigg boss 13', 'choti sardarni', 'bepanah pyar']
# Sunil Grover, who ha
# ['sunil grover', 'putki', 'putki']
# 0.3
# --------------------- 234 -----------------------
# VANCOUVER -- Police
# ['vancouver', 'gabriola island', 'camp miriam']
# RCMP have launched a
# ['rcmp', 'gabriola island', "jesse o'donaghey"]
# 0.2777777777777778
# --------------------- 235 -----------------------
# ​Wolves winger Adama
# ['adama traore', 'real madrid', 'barcelona']
# Adama Traoré is one
# ['adama traoré', 'wolverhampton', 'spanish']
# 0.16666666666666666
# --------------------- 237 -----------------------
# In an unusual event,
# ['malaysia', 'kuantan', 'facebook']
# Among the many reaso
# ['twitterati', 'soni', 'geetika vidya ohlyan']
# 0.22580645161290322
# --------------------- 239 -----------------------
# (MENAFN - Saudi Pres
# ['menafn   saudi press agency', 'riyadh', 'the official spokesman']
# (MENAFN- Kuwait News
# ['menafn  kuwait news agency', 'saudi', 'king salman airbase']
# 0.18518518518518517
# --------------------- 241 -----------------------
# Former NBA Commissio
# ['nba', 'david stern', 'the national sports league']
# Former National Bask
# ['national basketball association', 'david stern', 'stern']
# 0.1935483870967742
# --------------------- 242 -----------------------
# Elizabeth Martin giv
# ['elizabeth martin', 'mila', 'mila']
# FAYETTEVILLE, Ark. (
# ['fayetteville', 'ark', 'the university of arkansas’s office of sustainability']
# 0.07142857142857142
# --------------------- 244 -----------------------
# (MENAFN- Emirates Ne
# ['emirates news agency', 'wam', 'abu dhabi']
# Filed on January 2,
# ['mohamed bin zayed', 'arab', 'mohammed bin salman']
# 0.15384615384615385
# --------------------- 246 -----------------------
# COLUMBIA CITY, Ind.
# ['columbia city', 'ind', 'ap']
# MISHAWAKA, Ind. (AP)
# ['mishawaka', 'ind', 'ap']
# 0.1875
# --------------------- 247 -----------------------
# Buttigieg is the fir
# ['buttigieg', 'democratic', 'buttigieg']
# South Bend Mayor Pet
# ['pete buttigieg', 'buttigieg', 'democratic']
# 0.38461538461538464
# --------------------- 248 -----------------------
# Eberechi Eze and Bri
# ['eberechi eze', 'queens park rangers', 'cardiff city']
# Nigerian duo Eberech
# ['nigerian', 'eberechi eze', 'queens park rangers']
# 0.4090909090909091
# --------------------- 249 -----------------------
# January
#
# Steve Sisol
# ['steve sisolak', 'nevada', 'supreme court']
# VATICAN CITY — The y
# ['vatican city', 'francis', 'pope']
# 0.004273504273504274
# --------------------- 250 -----------------------
# Jack Grealish booste
# ['jack grealish', 'aston villa', 'turf moor']
# Struggling Aston Vil
# ['aston villa', 'burnley', 'turf moor']
# 0.2857142857142857
# --------------------- 252 -----------------------
#
#
# (Image by SANA) De
# ['dmca', 'syrians', 'sunnis']
# The Archbishop of Ca
# ['the archbishop of canterbury', 'justin portal welby', 'christians']
# 0.10526315789473684
# --------------------- 253 -----------------------
# From Truthdig
#
#
#
# Car
# ['truthdig\n\n\n\ncarbon', 'brian boucheron / flickr', 'the us house of representatives']
# As we head into the
# ['the roaring twenties 20', 'senate', 'donald trump']
# 0.07142857142857142
# --------------------- 254 -----------------------
# Hours after North Ko
# ['north korean', 'kim jong un', 'donald trump']
# North Korean leader
# ['north korean', 'kim jong un', 'north korean']
# 0.4
# --------------------- 255 -----------------------
# ‘Tell them that we C
# ['christians', 'east', 'west']
# » 05/03/2010 09:56
#
#
# ['christian', 'mosul', 'the university of mosul']
# 0.12195121951219512
# --------------------- 256 -----------------------
# HYDERABAD: A 37-year
# ['chennai', 'panjagutta', 'osmania general hospital']
# The 37-year-old woma
# ['panjagutta police station', 's lokeshwari', 's praveen kumar']
# 0.2222222222222222
# --------------------- 257 -----------------------
# Sarah Tew/CNET
#
# CES
# ['sarah tew/cnet', 'atari', 'las vegas']
# James Martin/CNET
#
# T
# ['james martin/cnet', 'cnet', 'apple arcade']
# 0.2
# --------------------- 259 -----------------------
# NYTimes Bret Stephen
# ['nytimes bret stephens', 'donald trump', 'republican']
# As for 2020, unemplo
# ['cembalest', 'bill clinton’s', 'late ’90s']
# 0.22
# --------------------- 261 -----------------------
# Click to email this
# ['opens', 'matt lauer', 'shamin abas']
# It looks like Matt L
# ['matt lauer', 'today', 'shamin abas']
# 0.34210526315789475
# --------------------- 264 -----------------------
# From Common Dreams
#
#
# ['bernie', 'bernie sanders', 'the new york times']
# Ready to fight back?
# ['the nation’s', 'subscribe', 'the nation’s']
# 0.14285714285714285
# --------------------- 265 -----------------------
#
#
# (Image by Egberto
# ['egberto willies', 'dmca', 'trump']
#
#
# (Image by Egberto
# ['egberto willies', 'dean obeidallah', 'msnbc']
# 0.2
# --------------------- 266 -----------------------
# LUDHIANA: The Centra
# ['the central bureau of investigation', 'indian revenue service', 'irs']
# The CBI on Wednesday
# ['cbi', 'directorate of revenue intelligence', 'chander shekhar']
# 0.16666666666666666
# --------------------- 267 -----------------------
# IIT-Kanpur
#
# Action a
# ['iit', 'iit k', 'ians']
# Kanpur: Poet Faiz Ah
# ['ahmad faiz', 'pakistan', 'indian']
# 0.13793103448275862
# --------------------- 268 -----------------------
# × Expand Courtesy Mi
# ['midtown sushi & ramen', 'spicy midtown', 'new miso butter']
# × Expand FeatureChin
# ['ap images robots', 'qinhuangdao', 'china']
# 0.08333333333333333
# --------------------- 269 -----------------------
# Laura Farber is the
# ['laura farber', 'latina', 'the tournament of roses association']
# Who could blame Sand
# ['sandra brockman', 'the rose parade', 'southern californians']
# 0.17424242424242425
# --------------------- 270 -----------------------
# (MENAFN)
#
#
#
#
#
# The ca
# ['menafn', 'faw volkswagen automobile co, ltd', 'audi']
# (MENAFN)
#
#
#
# Official
# ['menafn', 'china', 'the national development and reform commission']
# 0.2857142857142857
# --------------------- 273 -----------------------
# Separated from their
# ['thai', 'ban ta klang', 'thailand']
# Marium, a baby dugon
# ['marium', 'ko libong', 'thailand']
# 0.045454545454545456
# --------------------- 274 -----------------------
# Shares of CBRE Group
# ['cbre group', 'cbre group', 'the zacks real estate   operations']
# Investors seek growt
# ['the zacks growth style score', 'the zacks style scores', 'zacks rank']
# 0.25
# --------------------- 275 -----------------------
# Death can be an 'exc
# ['forbes', "dead rich list'", 'forbes']
# PHILADELPHIA (CBS) —
# ['philadelphia', 'cbs', 'google']
# 0.029850746268656716
# --------------------- 276 -----------------------
# Mumbai: The year gon
# ['mumbai', 'indian', 'wework’s']
# NEW YORK • Fireworks
# ['new york', 'new york city', 'times square']
# 0.05714285714285714
# --------------------- 278 -----------------------
# Starting New Year’s
# ['new year’s day', 'californians', 'scott w pink']
# The last five years
# ['uk', 'hiscox', 'ransomware']
# 0.09803921568627451
# --------------------- 280 -----------------------
# Your browser does no
# ['projekt', 'blade runner', 'rpg']
# The technical arm of
# ['eurogamer', 'digital foundry', 'amd']
# 0.10810810810810811
# --------------------- 281 -----------------------
# Lately, Sara Ali Kha
# ['sara ali khan', 'ibrahim khan', 'bollywood']
# Master blaster Sachi
# ['sachin tendulkar', 'madda ram', 'madda ram']
# 0.20588235294117646
# --------------------- 283 -----------------------
# Taiwan’s Air Force G
# ['taiwan', 'air force', 'shen yi ming']
# Air Force General Sh
# ['air force', 'shen yi ming', 'air force']
# 0.17647058823529413
# --------------------- 286 -----------------------
# From Strategic Cultu
# ['north korea', 'trump', 'china']
# NATIONAL
#
# (AP-Yonhap
# ['national', 'ap', 'washington']
# 0.21212121212121213
# --------------------- 289 -----------------------
# 2020 is here and the
# ['shehnaz gill', 'rashami desai', 'rashami']
# Sunil Grover, who ha
# ['sunil grover', 'putki', 'putki']
# 0.32075471698113206
# --------------------- 291 -----------------------
# Tim Kurkjian explain
# ['tim kurkjian', 'the tampa bay rays', 'tim kurkjian']
# Nearly every day I r
# ['baltimore hyatt regency', 'bud selig’s', 'inner harbor']
# 0.05128205128205128
# --------------------- 292 -----------------------
# THE four Haitians wh
# ['haitians', 'portland', 'st margaret']
# KINGSTON — A 28-year
# ['kingston', 'kingston', 'kingston police']
# 0.05263157894736842
# --------------------- 293 -----------------------
# LONDON (Reuters) - Q
# ['london', 'reuters', 'qatar investment authority']
# BEIJING (Reuters) -
# ['reuters', 'china', 'us senate']
# 0.06666666666666667
# --------------------- 294 -----------------------
# DETROIT – Detroit Li
# ['detroit', 'detroit lions', 'marvin jones']
# ALLEN PARK -- Detroi
# ['allen park', 'detroit lions', 'christian jones']
# 0.21739130434782608
# --------------------- 295 -----------------------
# New Delhi: Union law
# ['new delhi', 'ravi shankar prasad', 'parliament']
# As several states ha
# ['citizenship amendment act', 'the ministry of home affairs', 'the kerala assembly']
# 0.25
# --------------------- 296 -----------------------
# Grab country head fo
# ['philippines', 'brian cu', 'jonathan cellona']
# MANILA, Philippines
# ['manila', 'philippines', 'lrt']
# 0.045454545454545456
# --------------------- 297 -----------------------
# Rajan Prabhu, a proc
# ['rajan prabhu', 'prabhu', 'biomall']
# Pope Francis apologi
# ['francis', 'catholic', 'new year eve']
# 0.2
# --------------------- 299 -----------------------
# Feb 9, 2019 The Char
# ['peacevoice', 'james a haught', 'the cold war']
# reprinted from Dayli
# ['daylight atheism', 'peacevoice', 'jennings randolph']
# 0.04
# --------------------- 301 -----------------------
# × Pope Francis equat
# ['francis', 'francis', 'st peter’s basilica']
# Pope Francis has apo
# ['francis', 'st peter’s square', 'francis']
# 0.2857142857142857
# --------------------- 303 -----------------------
# ANCHORAGE, Alaska (A
# ['anchorage', 'alaska', 'ap']
# PARSIPPANY, N.J. (AP
# ['parsippany', 'nj', 'ap']
# 0.05555555555555555
# --------------------- 304 -----------------------
# On Christmas Eve, Sh
# ['shenzhen', 'penghua fund', 'etf']
# Pernambuco-based gro
# ['bci', 'tt work', 'moreno']
# 0.03333333333333333
# --------------------- 306 -----------------------
# The Senate President
# ['senate', 'ahmad lawan', 'nigerians']
# President Muhammadu
# ['muhammadu buhari', 'buhari', 'the african continental free trade area']
# 0.3333333333333333
# --------------------- 307 -----------------------
# It is the time of ma
# ['donald j trump', 'trump', 'russia']
# With all the talk of
# ['ukraine', 'american', 'the minsk agreement']
# 0.09615384615384616
# --------------------- 308 -----------------------
#
#
#
#
# GUARDIAN, ATLANT
# ['syrian', 'assad', 'russians']
# There is much angst
# ['freedom flotilla ii', 'israel', 'eric walberg']
# 0.013513513513513514
# --------------------- 309 -----------------------
# VK Vijayakumar
#
# Duri
# ['india', 'rbi', 'the public sector borrowing requirement']
# BSP supremo Mayawati
# ['bsp', 'mayawati', 'bjp']
# 0.043478260869565216
# --------------------- 310 -----------------------
# There’s nothing more
# ['meghana gulzar', 'laxmi aggarwal', 'india']
# Ajay Devgn is all se
# ['ajay devgn', 'india', 'indo pak war']
# 0.19607843137254902
# --------------------- 311 -----------------------
# A prominent media mo
# ['pakistan', 'hameed haroon', 'pakistani']
# Hundreds of patients
# ['nhs england', 'calea', 'runcorn']
# 0.03812316715542522
# --------------------- 314 -----------------------
# A Montana man was ar
# ['montana', 'daniel scheihing', 'yellowstone county']
# RAPID CITY, S.D. (AP
# ['rapid city', 'sd', 'ap']
# 0.14814814814814814
# --------------------- 315 -----------------------
# Start the New Year o
# ['the new year', 'the kent street activity centre', 'the kent street activity centre']
# There are a lot of f
# ['the new year', 'course', 'jenn']
# 0.07142857142857142
# --------------------- 316 -----------------------
# A hotel chain is sla
# ['the texas hill country', 'wyndham hotels & resorts', 'dolce hotels']
# Texas has long faced
# ['texas', 'canada', 'us']
# 0.05128205128205128
# --------------------- 317 -----------------------
# Advertisement
#
# While
# ['uk', 'new year', 'kirkwall']
# Poor old Rudolph (Pi
# ['rudolph', 'the north sea', 'rudolph']
# 0.06976744186046512
# --------------------- 318 -----------------------
# Palghar: A 37-year-o
# ['palghar', 'maharashtra', 'santosh shende']
# Palm Beach: US Presi
# ['palm beach', 'us', 'donald trump']
# 0.2916666666666667
# --------------------- 319 -----------------------
# To view this video p
# ['javascript', 'html5', 'us']
# WASHINGTON (AP) — Pr
# ['washington', 'ap', 'donald trump']
# 0.3939393939393939
# --------------------- 320 -----------------------
# The Indian Space Res
# ['the indian space research organisation', 'gaganyaan', 'russia']
# Jan 01, 2020 , 4:59P
# ['iaf', 'russia', 'gaganyaan mission']
# 0.3125
# --------------------- 321 -----------------------
# “This is very differ
# ['mallacoota', 'abc news', 'andrews']
# At least 17 people r
# ['east gippsland', 'bairnsdale', 'victorian']
# 0.05128205128205128
# --------------------- 322 -----------------------
# A 19-year-old man ha
# ['co derry', 'new year’s day', 'the moneysharvan road']
# Police attended the
# ['michael og mckenna', 'co londonderry', 'new year']
# 0.2
# --------------------- 323 -----------------------
# Whether it’s art, an
# ['european', 'uk', 'european']
# A+ A-
#
# London: Resea
# ['annals of internal medicine', 'cathepsin k inhibitor', 'us']
# 0.08333333333333333
# --------------------- 324 -----------------------
# Whistleblower settle
# ['the oregon office of emergency management', 'laurie holien', 'holien']
# Please enable Javasc
# ['javascript', 'san diego', 'earned sick leave and']
# 0.043478260869565216
# --------------------- 326 -----------------------
# Sign up to FREE dail
# ['free', 'invalid email\n\nfans', 'quadrantids']
# The name attached to
# ['orionid', 'orion', 'earth']
# 0.1111111111111111
# --------------------- 327 -----------------------
# Photos: San Antonio
# ['san antonio', 'new year eve', 'the new year']
# Visitors and locals
# ['san antonio', 'new year’s eve', 'celebrate sa']
# 0.07692307692307693
# --------------------- 328 -----------------------
# Kevin Holland Jo Bam
# ['kevin holland', 'jo bamford', 'tom gentile']
# 'As we enter 2020, l
# ['northern ireland', 'new year eve', 'https://wwwbelfasttelegraphcouk/opinion/editors viewpoint/editors viewpoint let us refocus on a better future for all 38823468html']
# 0.06896551724137931
# --------------------- 329 -----------------------
# CALGARY—Hilary Chapp
# ['calgary', 'hilary chapple', 'alberta']
# It’s a show of epic
# ['albertan', 'north america', 'edmonton']
# 0.13333333333333333
# --------------------- 330 -----------------------
# Mark Twain was once
# ['mark twain', 'northern california', 'don russell']
# LOS ANGELES (AP) — T
# ['los angeles', 'ap', 'the golden globes']
# 0.022222222222222223
# --------------------- 331 -----------------------
# Bobbi Kristina Brown
# ['kristina brown’s', 'nick gordon', 'jack walker']
# Click to email this
# ['opens', 'twitter', 'opens']
# 0.2692307692307692
# --------------------- 333 -----------------------
# ST. CATHARINES, Ont.
# ['catharines', 'ont', 'st catharines']
# HALIFAX -- Halifax p
# ['halifax', 'halifax regional police', 'the canadian press']
# 0.1111111111111111
# --------------------- 335 -----------------------
# Washington, DC - It
# ['washington', 'dc', 'us']
# Look ahead: Twenty t
# ['the middle east', 'saudi arabia', 'riyadh']
# 0.09375
# --------------------- 336 -----------------------
# Sign up to FREE dail
# ['free', 'invalid email', 'cornwall']
# Sign up to FREE dail
# ['free', 'invalid email', 'martin freeman']
# 0.09090909090909091
# --------------------- 337 -----------------------
# ROCKWOOD -- The Huds
# ['new year’s day', 'the eramosa river', 'grandma']
# Sign up to FREE dail
# ['free', 'leicestermercury   daily subscribe', 'invalid email']
# 0.125
# --------------------- 339 -----------------------
# Victims of Johnson C
# ['johnson county', 'kansas city', 'the kansas highway patrol']
# The pilot and passen
# ['the johnson county executive airport', 'arkansas', 'texas']
# 0.34375
# --------------------- 340 -----------------------
# Golf Stand Bag Marke
# ['"global golf stand bag industry', 'state', 'size, share']
# Precast Concrete Con
# ['precast concrete construction market 2020 industry demand, share, trend, industry news', 'business statistics', 'forecast']
# 0.25925925925925924
# --------------------- 341 -----------------------
# Here we go again, st
# ['trump', 'homelessness', 'california']
# Left-wing Hollywood
# ['hollywood', 'donald trump', 'the people’s house']
# 0.03
# --------------------- 344 -----------------------
#
#
# Bill Fugate, direc
# ['middletown', 'ohio', 'amy powell']
# A new year typically
# ['us', 'oregon', 'oregon']
# 0.07936507936507936
# --------------------- 348 -----------------------
# A lawsuit that accus
# ['kevin spacey', 'federal district court', 'california']
# A federal lawsuit fi
# ['kevin spacey', 'malibu', 'los angeles']
# 0.2222222222222222
# --------------------- 350 -----------------------
# Sign up to FREE dail
# ['free', 'invalid email', 'new year eve']
# Sign up to FREE dail
# ['free', 'invalid email', 'staffordshire']
# 0.3142857142857143
# ...
# BERLIN (REUTERS) - S
# ['reuters', 'german', 'norbert roettgen']
# 0.20689655172413793
# --------------------- 2504 -----------------------
# The former SPD boss
# ['spd', 'sigmar gabriel handerts', 'social democrats']
# MOSCOW (Sputnik) - T
# ['moscow', 'german', 'angela merkel']
# 0.17857142857142858
# --------------------- 2505 -----------------------
# The liberal throw Al
# ['altmaier', 'german', 'fdp']
# A split has emerged
# ['german', 'peter altmaier', 'christian']
# 0.08695652173913043
# --------------------- 2506 -----------------------
# Docu About basketbal
# ['michael jordan', 'espn', 'michael jordan   and']
# Former Chicago Bulls
# ['chicago bulls', 'michael jordan', 'the last dance']
# 0.28
# --------------------- 2507 -----------------------
# Grünheide The US Ele
# ['us', 'electroautobauer tesla', 'europe']
# According to the Bra
# ['brandenburg', 'europe', 'potsdam']
# 0.21428571428571427
# --------------------- 2508 -----------------------
# The Japanese automak
# ['japanese', 'mitsubishi', 'german']
# German prosecutors o
# ['german', 'mitsubishi', 'german']
# 0.25
# --------------------- 2509 -----------------------
# The Lufthansa Group
# ['the lufthansa group', 'frankfurt', 'europe']
# FILE PHOTO: Planes o
# ['german', 'lufthansa', 'frankfurt']
# 0.32142857142857145
# --------------------- 2510 -----------------------
# The EU Commission wa
# ['the eu commission', 'eu', 'thierry breton']
# Whole-country quaran
# ['the united states', 'europeans', 'the united states']
# 0.1724137931034483
# --------------------- 2511 -----------------------
# With their retreat a
# ['cdu', 'annegret kramp', 'thuringia']
# (MENAFN - Gulf Times
# ['menafn   gulf times', 'germany', 'christian democrats']
# 0.17307692307692307
# --------------------- 2512 -----------------------
# The Ebola epidemic s
# ['the united nations', 'un', 'west africa']
# The World Health Org
# ['the world health organization', 'the democratic republic of the', 'congo']
# 0.30434782608695654
# --------------------- 2513 -----------------------
# Berlin (DPA) - The F
# ['berlin', 'the federal government', 'corona']
# An information sheet
# ['coupons', "rosa canina'", 'berlin']
# 0.1
# --------------------- 2514 -----------------------
# Alira Health  Alira
# ['alira health  alira health', 'care factory', 'sas']
# WeShare, Volkswagen
# ['weshare', 'volkswagen', 'germany']
# 0.15555555555555556
# --------------------- 2516 -----------------------
# The Australian Cardi
# ['australian', 'the catholic church', 'george pell']
# Australian Cardinal
# ['australian', 'george pell', 'the supreme court of victoria']
# 0.28125
# --------------------- 2517 -----------------------
# Despite the Corona:
# ['corona', 'tom hanks', 'rita wilson']
# Jersey Shore star Je
# ['jersey shore', 'jenni "jwoww" farley', 'tom hanks']
# 0.3333333333333333
# --------------------- 2518 -----------------------
# The so-called Heinsb
# ['heinsberg', 'the university of bonn', 'heinsberg']
# The numbers of new c
# ['germany', 'reuters', 'the university of bonn']
# 0.17391304347826086
# --------------------- 2519 -----------------------
# Tehran-Sana, Iranian
# ['tehran', 'iranian', 'hassan rowhani']
# TEHRAN-SANA, Iranian
# ['tehran sana', 'iranian', 'hassan rohani']
# 0.3125
# --------------------- 2520 -----------------------
# The security service
# ['cairo', 'corona', 'the ministry of the interior']
# The investigations a
# ['the department of supply police', 'the suez security directorate', 'south sinai']
# 0.5
# --------------------- 2521 -----------------------
# The Libyan National
# ['the libyan national army', 'the libyan air force', 'libyan']
# Turkish President Er
# ['turkish', 'erdogan', 'libya']
# 0.23333333333333334
# --------------------- 2522 -----------------------
# Ahmed Abdel Rahman r
# ['ahmed abdel rahman', 'the iranian affairs', 'abed zadeya']
# The head of the Iran
# ['iranian', 'ali abed zada', 'ukrainian']
# 0.29411764705882354
# --------------------- 2523 -----------------------
# The visit of the vis
# ['ramadan', 'the ramadan hilal', 'ramadan']
# Written - Safia Alda
# ['ramadan', 'the islamic neighborhood', 'al hilal']
# 0.1282051282051282
# --------------------- 2524 -----------------------
# After the emperor of
# ['palestine', 'mashreq', 'the white house']
# The Kremlin said on
# ['kremlin', 'russia', 'us']
# 0.30158730158730157
# --------------------- 2525 -----------------------
# "The exhibition, whi
# ['red expeditions', 'britain', 'corona']
# British Prime Minist
# ['british', 'boris johnson', 'twitter']
# 0.1111111111111111
# --------------------- 2526 -----------------------
# The Public Security
# ['the public security sector', 'qena', 'qena sahrawi sahrawi']
# Subscribe to receive
# ['qena', 'al wakar', 'abucott']
# 0.3
# --------------------- 2527 -----------------------
# Despite her free fro
# ['corona', 'yemen', 'yemen']
# Follow-up March 20 T
# ['the joint technical committee', 'corona', 'abdul hakim al kahlani']
# 0.35714285714285715
# --------------------- 2528 -----------------------
# He said in a dialogu
# ['german', 'der spiegel', 'iranian']
# Iranian Foreign Mini
# ['iranian', 'mohammad jawad zarif', 'europe']
# 0.5714285714285714
# --------------------- 2529 -----------------------
# Tehran Still, the nu
# ['tehran', 'corona', 'iran']
# In recent days, Iran
# ['iran', 'iranian', 'iranian']
# 0.20833333333333334
# --------------------- 2530 -----------------------
# The price of the dol
# ['egyptian', 'egyptian', 'egyptian']
# The dollar's price o
# ['egypt', 'us', 'egyptian']
# 0.2727272727272727
# --------------------- 2532 -----------------------
# The Tourism Secretar
# ['the tourism secretariat', 'aswan', 'the tourism chamber']
# Major General Ashraf
# ['ashraf attia', 'aswan', 'the future party']
# 0.20833333333333334
# --------------------- 2533 -----------------------
# It is a little known
# ['the institut pasteur de dakar', 'ipd', 'amadou alpha sall']
# After hospitals, the
# ['the institut pasteur de dakar', 'amadou alpha sall', 'the pasteur institute']
# 0.5
# --------------------- 2535 -----------------------
# The daily record of
# ['algeria', 'the scientific committee', 'the monitoring of coronavirus']
# The COVID-19 balance
# ['algeria', 'the scientific committee', 'djamel fourar']
# 0.42857142857142855
# --------------------- 2536 -----------------------
# Receiving the creden
# ['russia', 'france', 'pierre lévy']
# Russia is "open to c
# ['russia', 'canada', 'arctic']
# 0.3684210526315789
# --------------------- 2537 -----------------------
# In 2020, Vietnam ass
# ['vietnam', 'asean', 'the united nations security council']
# The Chief of the Vie
# ['the vietnamese government', 'asean 2020', 'asean']
# 0.20588235294117646
# --------------------- 2538 -----------------------
# Mortality due to cor
# ['italy', 'the national institute for health in the report', 'rome']
# 1.2 percent of a gro
# ['italy', 'the national institute of health', 'photo hospital']
# 0.2
# --------------------- 2539 -----------------------
# "Gogglebox: in front
# ['gogglebox', 'poland', 'ttv']
# GIS brought to the a
# ['poles', 'coronavirus', 'gis']
# 0.07407407407407407
# --------------------- 2540 -----------------------
# Poland will be able
# ['poland', 'eu', 'polish']
# "In the coming days
# ['pandemia', 'chinese', 'wuhan']
# 0.2
# --------------------- 2542 -----------------------
# Vladimir Putin and a
# ['vladimir putin', 'russia', 'poland']
# The Chairman of the
# ['the foreign affairs committee', 'russian', 'leonid słucki']
# 0.2857142857142857
# --------------------- 2543 -----------------------
# "To all the boys I l
# ["to all the boys i've loved before", 'netflix', 'jenny han']
# NetFlix service is d
# ['netflix', 'recommended', 'netfliksi']
# 0.2631578947368421
# --------------------- 2545 -----------------------
# The average audience
# ['wavemaker', 'events', 'polsat']
# "Facts" TVN and TVN2
# ['bis', 'info', 'events']
# 0.13636363636363635
# --------------------- 2546 -----------------------
# The 10th anniversary
# ['smolensk', 'smolensk', 'witold waszczykowski']
# Nobody from the high
# ['smolensk', 'mep', 'pis witold waszczykowski']
# 0.3125
# --------------------- 2547 -----------------------
# Behind a series of f
# ['russian', 'rmf', 'polish']
# Initially, the suspi
# ["the polish teachers' union", 'the russian specifications', 'rmf fm']
# 0.4
# --------------------- 2548 -----------------------
# The cinema in Italy
# ['italy', 'the association of cinema halls', 'association']
# Presented numbers on
# ['italy', 'roberto burioni', 'burioni']
# 0.2
# --------------------- 2549 -----------------------
# 13 new coronavirus i
# ['opole', 'the ministry of health', 'kluczborski']
# 9 new cases on COVID
# ['knięciarcy', 'kędzierzyńsko', 'namysłowski']
# 0.3
# --------------------- 2550 -----------------------
# Members of the Assoc
# ['association', 'culture', 'poland']
# A letter to the prem
# ['matthew morawiecki', 'european', 'poland']
# 0.15151515151515152
# --------------------- 2551 -----------------------
# The New York Times m
# ['the new york times', 'russia', 'danielle rhodes']
# The Ministry of Fore
# ['the ministry of foreign affairs of russia', 'the financial times', 'the new york times']
# 0.11627906976744186
# --------------------- 2552 -----------------------
# This, however, was a
# ['dow jones', 'the world health organization', 'europe']
# On Thursday, a downw
# ['chinese', 'american', 'coronavirus']
# 0.14285714285714285
# --------------------- 2554 -----------------------
# - In the coming days
# ['denmark', 'germany', 'france']
# The Minister of Fore
# ['heiko maas', 'warsaw', 'prague']
# 0.47368421052631576
# --------------------- 2555 -----------------------
# "We have information
# ['jakub kaczmarczyk', 'kraka', 'warsaw']
# On Saturday, April 4
# ['kraska', 'coronavirus', 'poland']
# 0.36363636363636365
# --------------------- 2557 -----------------------
# The prices are still
# ['koronavirus', 'orlen', 'the przymarket stations / wojciech stróżyk']
# Below Market Comment
# ['wti ropa', 'usa', 'russia']
# 0.30434782608695654
# --------------------- 2558 -----------------------
# İnönü Municipality h
# ['i̇nönü municipality', 'inonu municipality', 'eskişehir i̇nönü municipality']
# In İnönü, the gospel
# ['the district of spring', 'eskişehir i̇nönü', 'martyrs park']
# 0.1875
# --------------------- 2559 -----------------------
# The Kashmir drama ha
# ['kashmir', 'the ak party', 'istanbul']
# President of Pakista
# ['pakistani', 'arif alvi', 'kashmir']
# 0.2558139534883721
# --------------------- 2561 -----------------------
# During a meeting in
# ['the russian ministry of defense', 'sergey şökgu', 'chemical']
# Russia will send mil
# ['russia', 'italy', 'kovid 19']
# 0.3333333333333333
# --------------------- 2562 -----------------------
# President Erdogan ag
# ['erdogan', 'kasapoğlu', 'football camia']
# Youth Muharrem Kasap
# ['muharrem kasapoğlu', 'muharrem kasapoğlu', 'mehmet muharrem kasapoğlu']
# 0.2413793103448276
# --------------------- 2563 -----------------------
# The 'Yoruk Anaya' Go
# ["yoruk anaya'", 'kayseri', 'tomarza']
# 21.02.2020 10:27 | L
# ['kayseri', 'baki ersoy', 'tbmm']
# 0.16
# --------------------- 2564 -----------------------
# Due to the coronavir
# ['turkey', 'agenda', 'european']
# Turkey Football Fede
# ['turkey football federation', 'tff', 'europe']
# 0.10256410256410256
# --------------------- 2565 -----------------------
# Ministry of Health C
# ['ministry of health coronavirus', 'science', 'kayseri city hospital property']
# Ministry of Health C
# ['ministry of health coronavirus', 'science', 'kayseri city hospital property']
# 0.4444444444444444
# --------------------- 2566 -----------------------
# The voltage between
# ['india', 'china', 'india']
# The Government of In
# ['india', 'chinese', 'i̇ktok']
# 0.8
# --------------------- 2567 -----------------------
# Our 2 soldiers in th
# ['idlib', 'şkit', 'syrian']
# Why is Turkey in Syr
# ['turkey', 'syria', 'idlib']
# 0.22580645161290322
# --------------------- 2568 -----------------------
# The Assad regime try
# ['assad', 'syria', 'russia']
# In the statement mad
# ['twitter', 'çna', 'the armed unmanned air tool']
# 0.15789473684210525
# --------------------- 2569 -----------------------
# 13.02.2020 12:19 | L
# ['isparta', 'school', 'isparta']
# 13.02.2020 17:02 | L
# ['isparta ay', 'isparta', 'martyr']
# 0.15789473684210525
# --------------------- 2570 -----------------------
# In the Saruhanli dis
# ['saruhanli', 'manisa', 'serkan burak']
# Manisa's Alisan and
# ['manisa', 'alisan', 'saruhanli']
# 0.17391304347826086
# --------------------- 2571 -----------------------
# In the report, the i
# ['china', 'north america', 'asia']
# The low growth figur
# ['euler hermes', 'konkordato', 'turkey']
# 0.25
# --------------------- 2572 -----------------------
# 15.02.2020 20:14 | L
# ['pegasus airlines', 'the istanbul   düsseldorf airport', 'pegaus airlines']
# The Pegasus aircraft
# ['sabiha gökçen düsseldorf', 'pegasus airlines', 'düsseldorf airport']
# 0.2222222222222222
# --------------------- 2573 -----------------------
# The Rahşian Ecevit h
# ['the rahse ecevit', 'bursa', 'bülent ecevit']
# The founder of the D
# ['the democratic left party', 'dsp', 'the democratic left party']
# 0.3055555555555556
# --------------------- 2574 -----------------------
# In Sakarya, two brot
# ['sakarya', 'the national solidarity campaign', 'the national solidarity campaign, misra']
# Donated half of the
# ['the national solidarity campaign', 'hüseyin aydin', 'keban']
# 0.16666666666666666
# --------------------- 2575 -----------------------
# According to the Dep
# ['the department of communication', 'oktay interior', 'süleyman soylu']
# AA President of Pres
# ['fuat oktay', 'interior', 'süneyman soylu']
# 0.21428571428571427
# --------------------- 2576 -----------------------
# 22.02.2020 13:16 | L
# ['antalya', 'halil özçelik', 'behçet']
# A different diagnosi
# ['sspe', 'sspe', 'özçelik']
# 0.125
# --------------------- 2577 -----------------------
# We need to solve the
# ['idlib', 'russia', 'moscow']
# President Recep Tayy
# ['recep tayyip erdogan', 'azerbaijan', 'libya']
# 0.1
# --------------------- 2578 -----------------------
# Gümüşhane quarantine
# ['gümüşhane', 'gumushane', 'belgium']
# Fenerbahce's Goalkee
# ['fenerbahce goalkeeper berke ozer goalkeeper', 'fenerbahce', 'fenerbahce']
# 0.2222222222222222
# --------------------- 2580 -----------------------
# Today, the President
# ['the presidential cabinet of the presidency cabinet', 'lgs', 'lgs']
# President Recep Tayy
# ['recep tayyip erdogan', 'the huber pavilion', 'tayyip erdogan']
# 0.07142857142857142
# --------------------- 2581 -----------------------
# A thousand 635 new c
# ['fahrettin husband', 'johns hopkins university', 'dw / bu']
# After the first case
# ['turkey', 'turkey', 'fahrettin husband']
# 0.2222222222222222
# --------------------- 2582 -----------------------
# What is the last sit
# ['corona virus', 'corona virus', 'corona']
# According to the US-
# ['us', 'johns hopkins university', 'us']
# 0.21052631578947367
# --------------------- 2583 -----------------------
# Visit to the festiva
# ['protocol', 'kutahya', 'omer toraman']
# 29.01.2020 12:11 | L
# ['child protection kütahya provincial coordination board', 'the evaluation meeting', 'omer toraman presidently']
# 0.2413793103448276
# --------------------- 2584 -----------------------
# In the statement mad
# ['mardin provincial directorate', 'gbt', 'the security commission']
# A person who sells t
# ['mardin', 'mardin', 'turkey']
# 0.08
# --------------------- 2585 -----------------------
# The UN announced tha
# ['un', 'aden', 'the united nations']
# In Yemen, Women's De
# ['yemen', 'women death risk warning explanation', 'the united nations']
# 0.3
# --------------------- 2586 -----------------------
# Because of the Kovid
# ['la liga clubs', 'football league', 'la liga']
# The new type of coro
# ['football league', 'la liga', 'spanish']
# 0.8571428571428571
# --------------------- 2587 -----------------------
# It is stated that th
# ['besiktas', 'ahmet nur dek', 'turkey banks association']
# TFF has published an
# ['tff', 'besiktas', 'team spend limits']
# 0.09090909090909091
# --------------------- 2588 -----------------------
# Ergene Municipality
# ['ergene municipality', 'tekirdag', 'ergene municipality']
# In Ergene, the mask
# ['ergene', 'ergene county', 'ergene']
# 0.16666666666666666
# --------------------- 2589 -----------------------
# DHKP-C Terrorist Org
# ['istanbul küçükarmutlu', 'gökcek esenyurt state hospital', 'gökçek orchencer']
# In the Criminal Cour
# ['the criminal court', 'the group commentation', 'the terrorist organization of the dhkp c terrorist organization']
# 0.03125

# %%
text_key_df.isna().sum()
# Out:
# pair_id             0
# url1_lang           0
# url2_lang           0
# text1               0
# text2               0
# translated_body1    0
# translated_body2    0
# key1                0
# key2                0
# key_score           0
# dtype: int64

# %%
text_key_df[text_key_df['translated_body1'].isna()]
# Out:
# Empty DataFrame
# Columns: [pair_id, url1_lang, url2_lang, text1, text2, translated_body1, translated_body2, key1, key2, key_score]
# Index: []

# %%
text_key_df
# Out:
#                     pair_id url1_lang url2_lang  \
# 0     1484084337_1484110209        en        en
# 1     1576314516_1576455088        en        en
# 2     1484036253_1483894099        en        en
# 3     1484034982_1483785560        en        en
# 4     1484188439_1484378177        en        en
# ...                     ...       ...       ...
# 2585  1586195445_1598778991        tr        tr
# 2586  1590915424_1590940388        tr        tr
# 2587  1526157103_1492737005        tr        tr
# 2588  1603274500_1618292937        tr        tr
# 2589  1597247537_1604202164        tr        tr
#
#                                                   text1  \
# 0     MARTINSBURG, W.Va. — A suspected drunken drive...
# 1     Uber has sold its online food-ordering busines...
# 2     BENGALURU (Reuters) - India has approved its t...
# 3     Asserting that India too should protect the in...
# 4     From The Guardian\n\nFrom Boeing to Whole Food...
# ...                                                 ...
# 2585  BM, Aden'de 2 bini aşkın iç göçmenin selden za...
# 2586  Kovid-19'dan dolayı La Liga kulüplerinde hayat...
# 2587  \n\n\n\n\n\n\n\nİflas noktasındaki kulüplerin ...
# 2588  Ergene Belediyesi yol çalışmalarına aksatmadan...
# 2589  DHKP-C Terör Örgütü üyeliğinden yargılanan ve ...
#
#                                                   text2  \
# 0     PORT-AU-PRINCE, Haiti — Haitian President Jove...
# 1     Rapid digitisation and growth in both online b...
# 2     BANGALORE: India plans to make a fresh attempt...
# 3     The air quality recorded at 9.38 am was 433 in...
# 4     Police have arrested a 38-year-old black man f...
# ...                                                 ...
# 2585  BM'den Yemen'de kadınların doğumda ölüm riski ...
# 2586  Yeni tip koronavirüs (Kovid-19) salgınının eko...
# 2587  TFF, resmi internet sitesinden Beşiktaş'ın fai...
# 2588  Ergene'de Ahimehmet ve Yeşiltepe mahallelerind...
# 2589  Ceza Mahkemesi'nde DHKP-C terör örgütü üyeliği...
#
#                                        translated_body1  \
# 0     MARTINSBURG, W.Va. — A suspected drunken drive...
# 1     Uber has sold its online food-ordering busines...
# 2     BENGALURU (Reuters) - India has approved its t...
# 3     Asserting that India too should protect the in...
# 4     From The Guardian\n\nFrom Boeing to Whole Food...
# ...                                                 ...
# 2585  The UN announced that more than 2,000 domestic...
# 2586  Because of the Kovid-19, the Survival Struggle...
# 2587  It is stated that the sales of the clubs at th...
# 2588  Ergene Municipality continues without disrupti...
# 2589  DHKP-C Terrorist Organization is tried from th...
#
#                                        translated_body2  \
# 0     PORT-AU-PRINCE, Haiti — Haitian President Jove...
# 1     Rapid digitisation and growth in both online b...
# 2     BANGALORE: India plans to make a fresh attempt...
# 3     The air quality recorded at 9.38 am was 433 in...
# 4     Police have arrested a 38-year-old black man f...
# ...                                                 ...
# 2585  In Yemen, Women's Death Risk Warning Explanati...
# 2586  The new type of coronavirus (Kovid-19) is cons...
# 2587  TFF has published an explanation on the offici...
# 2588  In Ergene, the mask was distributed in Ahimehm...
# 2589  In the Criminal Court, the Group Commentation ...
#
#                                                    key1  \
# 0     [martinsburg, wva, new year’s day, west virgin...
# 1     [india, zomato, china, ant financial, zomato, ...
# 2     [bengaluru, reuters, india, indian space resea...
# 3     [india, malaysia, indonesia, sea, indonesia, c...
# 4     [guardian, boeing, whole foods, donald trump, ...
# ...                                                 ...
# 2585  [un, aden, the united nations, un, yemen, the ...
# 2586  [la liga clubs, football league, la liga, span...
# 2587  [besiktas, ahmet nur dek, turkey banks associa...
# 2588  [ergene municipality, tekirdag, ergene municip...
# 2589  [istanbul küçükarmutlu, gökcek esenyurt state ...
#
#                                                    key2  key_score
# 0     [haiti, haitian, jovenel moïse, moïse, the nat...   0.045455
# 1     [india, google, boston consulting group, bcg, ...   0.121951
# 2     [india, indian space research organisation, k ...   0.318182
# 3                                 [met, meteorological]   0.000000
# 4     [orange country, ny, jews, hasidic, monsey, ha...   0.031250
# ...                                                 ...        ...
# 2585  [yemen, women death risk warning explanation, ...   0.300000
# 2586  [football league, la liga, spanish, the cadena...   0.857143
# 2587  [tff, besiktas, team spend limits, ahmet nur r...   0.090909
# 2588  [ergene, ergene county, ergene, ergene, ergene...   0.166667
# 2589  [the criminal court, the group commentation, t...   0.031250
#
# [2590 rows x 10 columns]

# %%
path = 'eval/_EVAL_text_named-entity_score.csv'
title_key_df.to_csv(path,index=False)
