# %%
import pandas as pd
i=0
path = str(i)+'.csv'
df = pd.read_csv(path)
# Out:
#      Unnamed: 0                                              title meta_lang  \
# 0    1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1    1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2    1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3    1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4    1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ..          ...                                                ...       ...
# 495  1484233856  Orange County man charged with federal hate cr...        en
# 496  1484698252  Bernie Sanders: If I Can’t Win An Election On ...        en
# 497  1576133644  Who Is Devin Nunes? Narrated by Gina Brillon |...        de
# 498  1484010768  Sonny Mehta, head of publisher Knopf, dies age...        en
# 499  1484047456  Census Test Proves Asking About Citizenship Do...       NaN
#
# ...

# %%
df = df.rename(columns={"Unnamed: 0":"news_num"})
df
# Out:
#        news_num                                              title meta_lang  \
# 0    1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1    1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2    1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3    1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4    1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ..          ...                                                ...       ...
# 495  1484233856  Orange County man charged with federal hate cr...        en
# 496  1484698252  Bernie Sanders: If I Can’t Win An Election On ...        en
# 497  1576133644  Who Is Devin Nunes? Narrated by Gina Brillon |...        de
# 498  1484010768  Sonny Mehta, head of publisher Knopf, dies age...        en
# 499  1484047456  Census Test Proves Asking About Citizenship Do...       NaN
#
# ...

# %%
i=1
path = str(i)+'.csv'
df1 = pd.read_csv(path)
df1 = df1.rename(columns={"Unnamed: 0":"news_num"})
df1
# Out:
#        news_num                                              title meta_lang  \
# 0    1559189239  COVID-19 : le fédéral donnera 2 000 $ par mois...        fr
# 1    1484772117  Jamie Oliver's wife Jools reveals sadness over...        en
# 2    1514751455  Michael C. Hall’s Princess Goes to the Butterf...        en
# 3    1515277116  Amy Klobuchar trails top four candidates with ...        en
# 4    1484698249  RINO Senator Susan Collins Joins Murkowski And...        en
# ..          ...                                                ...       ...
# 495  1483747717  Kane scores twice, leads Blackhawks to 5-3 win...        en
# 496  1484130702  Presuntos sicarios abren fuego contra vehículo...        es
# 497  1484267770  Gobierno logra ahorro de 7 mmdp en compra de m...        es
# 498  1484763343  Pak PM Imran Khan Says He Was 'Puzzled' When D...       NaN
# 499  1581124670  Influencer Girl in Hospital Wears Heavy Makeup...        en
#
# ...

# %%
df = pd.concat([df, df1], ignore_index=True)

# %%
df
# Out:
#        news_num                                              title meta_lang  \
# 0    1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1    1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2    1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3    1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4    1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ..          ...                                                ...       ...
# 995  1483747717  Kane scores twice, leads Blackhawks to 5-3 win...        en
# 996  1484130702  Presuntos sicarios abren fuego contra vehículo...        es
# 997  1484267770  Gobierno logra ahorro de 7 mmdp en compra de m...        es
# 998  1484763343  Pak PM Imran Khan Says He Was 'Puzzled' When D...       NaN
# 999  1581124670  Influencer Girl in Hospital Wears Heavy Makeup...        en
#
# ...

# %%
i= 2
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 1000
# df_temp len: 150

# %%
df
# Out:
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 1145  1484233777  Don’t spread invasive freshwater pests this su...       NaN
# 1146  1484039757  Man caught with class A drugs walks free from ...        en
# 1147  1484010668  Hong Kong’s Stock Market Is Beckoning, Despite...        en
# 1148  1483875467  Do people who eat really healthy to keep fit a...        en
# 1149  1484037949  Millennials spent the last decade struggling t...        en
#
# ...

# %%
i= 3
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 1150
# df_temp len: 150
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 1295  1484400612  Over 30 West Virginia Prison Guard Trainees Fi...       NaN
# 1296  1484037975  American Girl releases first hearing-impaired ...        en
# 1297  1484432868  Trump signs the TRACED Act, the first federal ...        en
# 1298  1483802881  Good Newwz box office collection Day 5: Akshay...        en
# 1299  1484332324  Another Bengal vs Centre tussle? Govt rejects ...        en
#
# ...

# %%
i= 4
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 1300
# df_temp len: 200
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 1495  1483851278  Some White Dude Wants To Apologize For His Peo...        en
# 1496  1484010218  Fashion maven Stacy London is 'in love' with a...        en
# 1497  1484703241            Art Scene: Top 10 Visual Art Highlights        en
# 1498  1559139344   Deux retraités matanais sont coincés en Équateur        fr
# 1499  1484061712  PM to inaugurate 5 DRDO Young Scientists’ Labs...        en
#
# ...

# %%
i= 5
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 1500
# df_temp len: 150
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 1645  1484168047  Bild-Quiz: Wie gut kennen Sie den Kanton Obwal...        de
# 1646  1484200876  Thailand lays out red carpet to welcome its 39...        en
# 1647  1484219009          Wall Street cerró su mejor año desde 2013        es
# 1648  1484013788  First Citizens Bank Completes Merger With Ente...       NaN
# 1649  1484106364        A Decade Marked By Outrage Over Drug Prices        en
#
# ...

# %%
i= 6
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 1650
# df_temp len: 150
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 1795  1523794757           El papel de la ficción dentro del teatro        es
# 1796  1484459076  Punjab: LIP’s Bains says will challenge state’...        en
# 1797  1556566256  Coronavirus : 115.600 neue Arbeitslose in Vorw...        de
# 1798  1483992981       Weather Forecast: Warmer Thursday and Friday        en
# 1799  1484189055  In France, successful insanity defense by kill...        en
#
# ...

# %%
i= 7
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 1800
# df_temp len: 150
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 1945  1766951389  Face au coronavirus, « en Inde, le petit monde...        fr
# 1946  1504077800  Ecuador sugiere revisar procedimientos de la CIDH       NaN
# 1947  1490149486  En visite en Turquie, Poutine scelle un rappro...        fr
# 1948  1484160145  ÖVP und Grüne einig: Schwarz-grüne Regierung i...        de
# 1949  1484085036  Año Nuevo 2020: recogen más de 57 tn de residu...        es
#
# ...

# %%
i= 8
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 1950
# df_temp len: 150
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 2095  1496646947                     Celebrations at Medieval Times        en
# 2096  1484188816  Inside the businesses of 5 YouTube creators wh...       NaN
# 2097  1558377216    Almanya’nın sipariş ettiği 6 milyon maske kayıp        tr
# 2098  1484006479       New From Prince William: the Earthshot Prize       NaN
# 2099  1484765175            Stets zuverlässige Stützen des Betriebs        de
#
# ...

# %%
i= 9
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 2100
# df_temp len: 150
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 2245  1484751481  Machete attack victim faces grim prognosis fol...        en
# 2246  1503837324  Cordarrelle Patterson talks Bears kick-returne...        en
# 2247  1484065088  Angriff auf US-Botschaft: Teheran demonstriert...        de
# 2248  1483805434                    Community calendar for Jan. 2-8        en
# 2249  1484022936                                                NaN        pl
#
# ...

# %%
i= 10
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 2250
# df_temp len: 150
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 2395  1483859003                                                NaN        pl
# 2396  1484804402  Crime reports for Anne Arundel and Howard coun...        en
# 2397  1559136540  La MRC de Marguerite-D’Youville prend les gran...        fr
# 2398  1484038703  Mark Twain once wrote for California’s oldest ...        en
# 2399  1484189234  GOP Gov. John Kasich on Impeachment, Climate, ...        en
#
# ...

# %%
i= 11
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 2400
# df_temp len: 150
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 2545  1483989589          Drug ring busted, drugs worth RM1m seized        en
# 2546  1484012158  Australian bushfires push country towards 'hum...        en
# 2547  1557867666  President Trump Extends Deadline To Obtain REA...        en
# 2548  1486942765            Spirits In The Night! Haunted Pub Crawl        en
# 2549  1484127346                                                NaN        pl
#
# ...

# %%
i= 12
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 2550
# df_temp len: 150
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 2695  1483801741  Azerbaijan’s president: 2019 will go down in h...        en
# 2696  1484010424  Does Great Atlantic Resources Corp. (CVE:GR) H...        en
# 2697  1484059419                                                NaN        en
# 2698  1484249679  Deutsche Bahn schult 400 Flüchtlinge um - Mitt...        de
# 2699  1558581161  Koronavirüs uyarılarını dikkate almadılar! Ant...        tr
#
# ...

# %%
i= 13
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 2700
# df_temp len: 150
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 2845  1484011087  The decade in dumb: Looking back on the sillie...        en
# 2846  1483817222  Surrounded by snow, Indian soldiers sing heart...        en
# 2847  1483984703  Auburn football team to honor Pat Sullivan wit...        en
# 2848  1484224052   'Hostile' chicken captured by police in Kentucky        en
# 2849  1513278458              Thüringen-Wahl: Nach Ramelow-Schlappe        de
#
# ...

# %%
i= 14
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 2850
# df_temp len: 150
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 2995  1483988775       Jaki wpływ ma kieliszek szampana na zdrowie?        pl
# 2996  1483874442  Pijany kierowca uciekał przed policją. Auto ud...        pl
# 2997  1484228495  Reporta CEPC saldo blanco durante noche de fin...        es
# 2998  1484325513              The Daily News' year in pictures 2019        en
# 2999  1484007539  Bensouda: No charges against Israelis nor Pale...        en
#
# ...

# %%
i= 15
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 3000
# df_temp len: 200
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 3195  1484451939  Winter blues? Columbus Metro Parks offers fami...        en
# 3196  1484189302  Women are behind the most successful uprisings...        en
# 3197  1483733400  EDITORIAL: There’s much to celebrate at the on...        en
# 3198  1483867298  Mocne słowa papieża Franciszka o przemocy wobe...        pl
# 3199  1483753550  “Los maestros anarquistas potenciaron los valo...        es
#
# ...

# %%
i= 16
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 3200
# df_temp len: 200
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 3395  1484202357                        Irak - Aktuelle Nachrichten        de
# 3396  1484033810  Sponsored: Flat roofs tend to have more proble...        en
# 3397  1484190416  Crown Princess Mary of Denmark stuns as the Da...        en
# 3398  1484078246  Jugendlicher zielt mit Waffe auf Polizisten un...        de
# 3399  1484189363  American Airlines Schedules The Boeing 787 To ...        en
#
# ...

# %%
i= 17
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 3400
# df_temp len: 200
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 3595  1508720644  POL-FR: Teningen: Verkehrsunfallflucht in der ...        de
# 3596  1533588597  Unfälle, gesperrte Bahnstrecken und Stromausfä...        de
# 3597  1483979826  Dschungelcamp 2020 (RTL): Prince Damien nach D...        de
# 3598  1484763683                         Vier Einsätze an Silvester        de
# 3599  1484110865  Anticipan que el 2020 será un año muy caluroso...        es
#
# ...

# %%
i= 18
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 3600
# df_temp len: 200
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 3795  1523475444                POL-BS: Täter kamen über den Balkon        de
# 3796  1483960826  Delhi: Amit Shah holds BJP meeting at party he...        en
# 3797  1484251335  Activó el tobogán: Pasajero causó evacuación d...        es
# 3798  1484188320  Person killed after being hit by train in Belfast        en
# 3799  1483840043  Centre may make process of granting citizenshi...        en
#
# ...

# %%
i= 19
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 3800
# df_temp len: 200
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 3995  1484012638  President: The Azerbaijani government is alway...        en
# 3996  1552954828     Karoline Preisler: "Immer Sicherheitsabstand!"        de
# 3997  1484186389  München: Passanten finden Baby in Hinterhof - ...        de
# 3998  1508523302    Bayern startet neue Gigabit-Internet-FÃ¶rderung        de
# 3999  1484089061  2 Dead, 2 Critical After SUV Enters Northern I...        en
#
# ...

# %%
i= 20
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 4000
# df_temp len: 200
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 4195  1504218181  Gobierno considera “parcial” y “poco objetivo”...        es
# 4196  1484299664  Leading and managing organisational change | T...        en
# 4197  1484250587  Proteste in Bagdad: Wie der Iran mit Hilfe ira...       NaN
# 4198  1484006642  2 injured in NE Portland shooting, suspect at ...        en
# 4199  1484369513         Türkis-Grün präsentiert Regierungsprogramm        de
#
# ...

# %%
i= 21
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 4200
# df_temp len: 200
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 4395  1484080805  Atheist group sends demand to IRS to investiga...        en
# 4396  1483818989  Ooredoo launches New Year offers for Shahry an...       NaN
# 4397  1484012251      Longford man accused of assault to face trial       NaN
# 4398  1558564279  En los vehículos podrá viajar como máximo una ...        es
# 4399  1535418267  Hannover: Verkehrspsychologe sieht keinen Tren...        de
#
# ...

# %%
i= 22
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 4400
# df_temp len: 200
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 4595  1484763362  Malaysian Couple Faces Flak for Using Ambulanc...       NaN
# 4596  1483978479  Sube a al menos 23 muertos el balance por las ...        es
# 4597  1483827739  Ambitne plany Mentzena na 2020 rok. Stawia na ...        pl
# 4598  1483987405  Briton killed after New Year's Eve firework ex...        en
# 4599  1484037802               Mark Ronson rocks the Hogmanay party        en
#
# ...

# %%
i= 23
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 4600
# df_temp len: 200
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 4795  1546436608  Marakkar Arabikadalinte Simham Cannot Be Compa...        en
# 4796  1484373239  Messi y Cristiano Ronaldo, los reyes de la década        es
# 4797  1559010941                   ŞİDDETİN BAHANESİ VİRÜS OLMAMALI        tr
# 4798  1483946190  La Hiena Barrios fue apuñalado en Córdoba y ha...        es
# 4799  1484258391  Bobbi Kristina Brown’s ex-fiancé Nick Gordon d...        en
#
# ...

# %%
i= 24
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 4800
# df_temp len: 200
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 4995  1580450051  Burger King is offering free kids meals in res...        en
# 4996  1484270606  3 Bold Predictions for Bills-Texans Wild Card ...       NaN
# 4997  1510603325  Vermisst Limburg: Mann verlässt Wohnung – und ...        de
# 4998  1484188786  Catholic Academy of Waterbury to reopen on Tue...        en
# 4999  1484452386  Jason Holder rested from first two ODIs agains...        en
#
# ...

# %%
i= 25
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 5000
# df_temp len: 200
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 5195  1484763681     „Bau durch nachhaltigen Protest beschleunigen“        de
# 5196  1484190345  Orange Is the New Black creator Jenji Kohan’s ...        en
# 5197  1484325278               "NU Day Resurrection and Liberation"       NaN
# 5198  1493943763  Fallece Carlos Girón, medallista en la Olimpia...        es
# 5199  1483803446  Train rides get costlier from today: Here's by...        en
#
# ...

# %%
i= 26
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 5200
# df_temp len: 200
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 5395  1484251731  Victoria police searching for missing man with...        en
# 5396  1484241811  Lion Country Safari introduces new baby lion cubs        en
# 5397  1558515869  Fenerbahçe koronavirüs testine girdi, sonuçlar...        tr
# 5398  1543583268                                  Oil to outperform        en
# 5399  1484038154  QSBS Taxes: How to Set up a Startup for Qualif...        en
#
# ...

# %%
i= 27
path = str(i)+'.csv'
df_temp = pd.read_csv(path)
df_temp = df_temp.rename(columns={"Unnamed: 0":"news_num"})
print('df len:', len(df.index))
print('df_temp len:',len(df_temp.index))
df = pd.concat([df, df_temp], ignore_index=True)
df
# Out:
# df len: 5400
# df_temp len: 145
#         news_num                                              title meta_lang  \
# 0     1484067970  Valle de México recibe 2020 con mala calidad d...       NaN
# 1     1536953314  MinInterior lideró en Cali Comisión de Segurid...       NaN
# 2     1547327916  El Speedagro Rally Argentina 2020 ha sido apla...        es
# 3     1484261908  Trump’s lawyer Giuliani says he’s willing to t...        en
# 4     1484076690  Reprime EU a manifestantes con gases lacrimóge...        es
# ...          ...                                                ...       ...
# 5540  1484101809  AAP slams Congress, previous SAD-BJP alliance ...        en
# 5541  1484040153  Start the Year on a Positive Note With These S...        en
# 5542  1484188201  Everything new to Netflix in January and what ...       NaN
# 5543  1484125412  Zagłada ptaków w Polsce. W środę zabijały je w...       NaN
# 5544  1484205799  As Brexit Pulls Britain Apart, It Could Bring ...        en
#
# ...

# %%
df = df.rename(columns={"news_num":"id"})
path = 'all_training_with_translated_title.csv'
df.to_csv(path,index=False)
